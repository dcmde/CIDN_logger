# %%
# %config Completer.use_jedi = False
# %matplotlib notebook
import pandas as pd

# %%
data = pd.read_csv("./log 12-04-2021-15-00-00.txt",sep=" ")
data.head()
# Out:
#    alt  alt_msl      roll     pitch       yaw      lat      lon   vx   vy
# 0  0.0    317.0  0.005051  0.005041 -0.005738  45.6272  6.32983  0.0  0.0
# 1  0.0    317.0  0.005041  0.005040 -0.005717  45.6272  6.32983  0.0  0.0
# 2  0.0    317.0  0.005094  0.005092 -0.005713  45.6272  6.32983  0.0  0.0
# 3  0.0    317.0  0.005141  0.005168 -0.005685  45.6272  6.32983  0.0  0.0
# 4  0.0    317.0  0.005164  0.005121 -0.005597  45.6272  6.32983  0.0  0.0

# %%
data.plot(y='alt')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.plot(y=['vx','vy'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.plot(y=['roll','pitch','yaw'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.plot(y='lon')
data.plot(y='lat')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
